# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font family: Consolas; font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family: Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding top:120px;}
div.text_cell_render ul li {font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font family: Consolas; font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family: Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding top:120px;}
# div.text_cell_render ul li {font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# <b><font color="red" size="5"> Untitled </font></b>

# %%
# 12분 08초
sum = 0
for i in range(1, 101):
    sum += i
print(sum)
# Out:
# 5050

# %%
sum = 0
n = int(input("n: "))

for j in range(1, n + 1):
    for i in range(1, n + 1):
        sum += 1

print(sum)
# Out:
# n: 4
# 16

# %%
import time

#시작시간 기록
for i in range(1000000):
    resurt = i ** 2
    
#종료시간 기록
end_time = time.time()

# %%
import timeit

def test_function():
    for i in range(1000000):
        result = i ** 2
        
#실행시간 측정
execution_time = timeit.timeit(test_function, number = 1)
print(f'코드 실행시간 : {execution_time:.6f}초')
# Out:
# 코드 실행시간 : 0.293783초

# %%
import itertools

iterable1 = 'ABCD'
iterable2 = 'xy'
iterable3 = '1234'
print(list(itertools.product(iterable1, iterable2, iterable3)))
a = list(itertools.product(iterable1, iterable2, iterable3))
# Out:
# [('A', 'x', '1'), ('A', 'x', '2'), ('A', 'x', '3'), ('A', 'x', '4'), ('A', 'y', '1'), ('A', 'y', '2'), ('A', 'y', '3'), ('A', 'y', '4'), ('B', 'x', '1'), ('B', 'x', '2'), ('B', 'x', '3'), ('B', 'x', '4'), ('B', 'y', '1'), ('B', 'y', '2'), ('B', 'y', '3'), ('B', 'y', '4'), ('C', 'x', '1'), ('C', 'x', '2'), ('C', 'x', '3'), ('C', 'x', '4'), ('C', 'y', '1'), ('C', 'y', '2'), ('C', 'y', '3'), ('C', 'y', '4'), ('D', 'x', '1'), ('D', 'x', '2'), ('D', 'x', '3'), ('D', 'x', '4'), ('D', 'y', '1'), ('D', 'y', '2'), ('D', 'y', '3'), ('D', 'y', '4')]

# %%
a.shape
# Out:
# ------------------------------------------
# AttributeErrorTraceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
import random
a=("백돈","엽떡")
print(random.choice(a))
# Out:
# 엽떡

# %%
a = int(input().strip())
b = int(input().strip())

print(f"a = {a}")
print(f"b = {b}")
# Out:
# 4
# 5
# a = 4
# b = 5

# %% [markdown]
# # 웹크롤링

# %%
# 방법1 requests모듈
import requests
from bs4 import BeautifulSoup
url = 'https://www.yes24.com/product/category/bestseller?CategoryNumber=001&SumGb=02&pid=123487&cosemkid=go14913756400533498&utm_source=google_pc&utm_medium=cpc&utm_campaign=book_pc&utm_content=ys_240530_google_pc_cc_book_pc_yes24&utm_term=yes24%eb%b2%a0%ec%8a%a4%ed%8a%b8%ec%85%80%eb%9f%ac&gad_source=1&gad_campaignid=57752190&gbraid=0AAAAAD79Irpn6yOBw_-tFRQGS_7tiJXNW&gclid=Cj0KCQjwxdXBBhDEARIsAAUkP6hpmfi7gQxu34Pi8dR3GuIU986DS6fi_2Wsvno21Lv0itMmYtrQlBkaAteyEALw_wcB'
response = requests.get(url)
#response, response.status_code
#response.content
#response.content.decode('cp949')
#response.text
soup = BeautifulSoup(response.text, # response.content
                    'html.parser') #xml이면 xml.parser

# %%
# 책제목 1페이지 24개
title = soup.select('a.gd_name')
for t in title:
    print(t.text, end='\t')
# Out:
# 청춘의 독서	엄마의 말 연습	어른의 품격을 채우는 100일 필사 노트	단 한 번의 삶	이로운 보수 의로운 진보	소년이 온다	어른의 행복은 조용하다	초역 부처의 말	모순	빛과 실	쇼펜하우어 인생수업 : 한 번뿐인 삶 이렇게 살아라 (리커버 에디션)	듀얼 브레인	괴수 8호 15 트리플특장판	길고양이와 늑대 5 더블특전판	혼모노	위버멘쉬	결국 국민이 합니다	급류	에그박사 15	첫 여름, 완주	친구가 상처 줄 때 똑똑하게 나를 지키는 법	친구 사이에도 예의가 필요해	서랍에 저녁을 넣어 두었다	워런 버핏 웨이

# %%
# 책가격 1페이지 24개
price = soup.select('strong.txt_num>em.yes_b')
price_num = [round(float(p.text.replace(',',''))) for p in price]

# %%
# 가격에 원 붙히기
prices = price_num
prices_with_won = list(map(lambda x: str(x) + "원", prices))
prices_with_won
# Out:
# ['17010원',
#  '15750원',
#  '18000원',
#  '15120원',
#  '18000원',
#  '13500원',
#  '16020원',
#  '16020원',
#  '11700원',
#  '13500원',
#  '15750원',
#  '18900원',
#  '5400원',
#  '5400원',
#  '16200원',
#  '16020원',
#  '19800원',
#  '12600원',
#  '14220원',
#  '15300원',
#  '15120원',
#  '15300원',
#  '10800원',
#  '29700원']

# %%
for idx in range(len(title)):
    print("{} : {} - {}".format(idx+1,
                                  title[idx].text,
                                 prices_with_won[idx],
                                 ))
# Out:
# 1 : 청춘의 독서 - 17010원
# 2 : 엄마의 말 연습 - 15750원
# 3 : 어른의 품격을 채우는 100일 필사 노트 - 18000원
# 4 : 단 한 번의 삶 - 15120원
# 5 : 이로운 보수 의로운 진보 - 18000원
# 6 : 소년이 온다 - 13500원
# 7 : 어른의 행복은 조용하다 - 16020원
# 8 : 초역 부처의 말 - 16020원
# 9 : 모순 - 11700원
# 10 : 빛과 실 - 13500원
# 11 : 쇼펜하우어 인생수업 : 한 번뿐인 삶 이렇게 살아라 (리커버 에디션) - 15750원
# 12 : 듀얼 브레인 - 18900원
# 13 : 괴수 8호 15 트리플특장판 - 5400원
# 14 : 길고양이와 늑대 5 더블특전판 - 5400원
# 15 : 혼모노 - 16200원
# 16 : 위버멘쉬 - 16020원
# 17 : 결국 국민이 합니다 - 19800원
# 18 : 급류 - 12600원
# 19 : 에그박사 15 - 14220원
# 20 : 첫 여름, 완주 - 15300원
# 21 : 친구가 상처 줄 때 똑똑하게 나를 지키는 법 - 15120원
# 22 : 친구 사이에도 예의가 필요해 - 15300원
# 23 : 서랍에 저녁을 넣어 두었다 - 10800원
# 24 : 워런 버핏 웨이 - 29700원

# %%
result = []
for idx in range(len(title)):
    print("{} : {} - {}".format(idx+1,
                                  title[idx].text,
                                 prices_with_won[idx],
                                 ))
result
# Out:
# 1 : 청춘의 독서 - 17010원
# 2 : 엄마의 말 연습 - 15750원
# 3 : 어른의 품격을 채우는 100일 필사 노트 - 18000원
# 4 : 단 한 번의 삶 - 15120원
# 5 : 이로운 보수 의로운 진보 - 18000원
# 6 : 소년이 온다 - 13500원
# 7 : 어른의 행복은 조용하다 - 16020원
# 8 : 초역 부처의 말 - 16020원
# 9 : 모순 - 11700원
# 10 : 빛과 실 - 13500원
# 11 : 쇼펜하우어 인생수업 : 한 번뿐인 삶 이렇게 살아라 (리커버 에디션) - 15750원
# 12 : 듀얼 브레인 - 18900원
# 13 : 괴수 8호 15 트리플특장판 - 5400원
# 14 : 길고양이와 늑대 5 더블특전판 - 5400원
# 15 : 혼모노 - 16200원
# 16 : 위버멘쉬 - 16020원
# 17 : 결국 국민이 합니다 - 19800원
# 18 : 급류 - 12600원
# 19 : 에그박사 15 - 14220원
# 20 : 첫 여름, 완주 - 15300원
# 21 : 친구가 상처 줄 때 똑똑하게 나를 지키는 법 - 15120원
# 22 : 친구 사이에도 예의가 필요해 - 15300원
# 23 : 서랍에 저녁을 넣어 두었다 - 10800원
# 24 : 워런 버핏 웨이 - 29700원
# []

# %% [markdown]
# ## 2페이지

# %%
# 방법1 requests모듈
import requests
from bs4 import BeautifulSoup
url = 'https://www.yes24.com/product/category/bestseller?categoryNumber=001&pageNumber=2&pageSize=24'
response = requests.get(url)
#response, response.status_code
#response.content
#response.content.decode('cp949')
#response.text
soup2 = BeautifulSoup(response.text, # response.content
                    'html.parser') #xml이면 xml.parser

# %%
# 책제목 2페이지 24개
title2 = soup2.select('a.gd_name')
for t in title2:
    print(t.text, end='\t')
# Out:
# 봄의 폭풍과 몬스터 6	흔한남매 19	2025 심우철 실전 동형 모의고사 Season 4	ETS 토익 정기시험 기출문제집 1000 Vol. 4 RC	2025 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 상	엔비디아 젠슨 황, 생각하는 기계	넥서스	스토너	최애의 아이 16 특별판	ETS 토익 정기시험 기출문제집 1000 Vol. 4 LC	2025 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 하	과자 사면 과학 드립니다	하루 한 장 나의 어휘력을 위한 필사 노트	파과 (리커버)	너에게 들려주는 단단한 말	돈의 흐름은 되풀이된다	2025 문동균 한국사 지방직 대비 실전 봉투모의고사	설민석의 한국사 대모험 33	진짜의 마인드	유대인의 상술	최애의 아이 16	질문의 격	2025 선재국어 최우선 실전 봉투 모의고사	작별하지 않는다

# %%
# 책가격 2페이지 24개
price2 = soup2.select('strong.txt_num>em.yes_b')
price_num2 = [round(float(p.text.replace(',',''))) for p in price2]

# %%
# 가격에 원 붙히기
prices2 = price_num2
prices_with_won2 = list(map(lambda x: str(x) + "원", prices2))
prices_with_won2
# Out:
# ['5400원',
#  '14220원',
#  '12960원',
#  '17820원',
#  '14850원',
#  '25200원',
#  '25020원',
#  '15120원',
#  '35100원',
#  '17820원',
#  '14400원',
#  '13500원',
#  '21420원',
#  '14220원',
#  '16200원',
#  '17100원',
#  '10800원',
#  '12600원',
#  '16650원',
#  '16920원',
#  '7110원',
#  '16020원',
#  '16200원',
#  '15120원']

# %%
result2 = []
for idx in range(len(title2)):
    print("{} : {} - {}".format(idx+25,
                                  title2[idx].text,
                                 prices_with_won2[idx],
                                 ))
result2
# Out:
# 25 : 봄의 폭풍과 몬스터 6 - 5400원
# 26 : 흔한남매 19 - 14220원
# 27 : 2025 심우철 실전 동형 모의고사 Season 4 - 12960원
# 28 : ETS 토익 정기시험 기출문제집 1000 Vol. 4 RC - 17820원
# 29 : 2025 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 상 - 14850원
# 30 : 엔비디아 젠슨 황, 생각하는 기계 - 25200원
# 31 : 넥서스 - 25020원
# 32 : 스토너 - 15120원
# 33 : 최애의 아이 16 특별판 - 35100원
# 34 : ETS 토익 정기시험 기출문제집 1000 Vol. 4 LC - 17820원
# 35 : 2025 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 하 - 14400원
# 36 : 과자 사면 과학 드립니다 - 13500원
# 37 : 하루 한 장 나의 어휘력을 위한 필사 노트 - 21420원
# 38 : 파과 (리커버) - 14220원
# 39 : 너에게 들려주는 단단한 말 - 16200원
# 40 : 돈의 흐름은 되풀이된다 - 17100원
# 41 : 2025 문동균 한국사 지방직 대비 실전 봉투모의고사 - 10800원
# 42 : 설민석의 한국사 대모험 33 - 12600원
# 43 : 진짜의 마인드 - 16650원
# 44 : 유대인의 상술 - 16920원
# 45 : 최애의 아이 16 - 7110원
# 46 : 질문의 격 - 16020원
# 47 : 2025 선재국어 최우선 실전 봉투 모의고사 - 16200원
# 48 : 작별하지 않는다 - 15120원
# []

# %%
result_append = result.append(result2)
print(result_append)
# Out:
# None

# %% [markdown]
# # 50개만 가져오기 (웹크롤링)

# %%
# 방법1 requests모듈
import requests
from bs4 import BeautifulSoup
url = 'https://www.yes24.com/product/category/bestseller?categoryNumber=001&pageNumber=1&pageSize=50'
response = requests.get(url)
soup = BeautifulSoup(response.text,
                    'html.parser')

# %%
# 책제목 1페이지 50개
titles = [t.text for t in soup.select('a.gd_name')]
print(titles)
# Out:
# ['청춘의 독서', '엄마의 말 연습', '어른의 품격을 채우는 100일 필사 노트', '단 한 번의 삶', '이로운 보수 의로운 진보', '소년이 온다', '어른의 행복은 조용하다', '초역 부처의 말', '모순', '빛과 실', '쇼펜하우어 인생수업 : 한 번뿐인 삶 이렇게 살아라 (리커버 에디션)', '듀얼 브레인', '괴수 8호 15 트리플특장판', '길고양이와 늑대 5 더블특전판', '혼모노', '위버멘쉬', '결국 국민이 합니다', '급류', '에그박사 15', '첫 여름, 완주', '친구가 상처 줄 때 똑똑하게 나를 지키는 법', '친구 사이에도 예의가 필요해', '서랍에 저녁을 넣어 두었다', '워런 버핏 웨이', '봄의 폭풍과 몬스터 6', '흔한남매 19', '2025 심우철 실전 동형 모의고사 Season 4', 'ETS 토익 정기시험 기출문제집 1000 Vol. 4 RC', '2025 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 상', '엔비디아 젠슨 황, 생각하는 기계', '넥서스', '스토너', '최애의 아이 16 특별판', 'ETS 토익 정기시험 기출문제집 1000 Vol. 4 LC', '2025 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 하', '과자 사면 과학 드립니다', '하루 한 장 나의 어휘력을 위한 필사 노트', '파과 (리커버)', '너에게 들려주는 단단한 말', '돈의 흐름은 되풀이된다', '2025 문동균 한국사 지방직 대비 실전 봉투모의고사', '설민석의 한국사 대모험 33', '진짜의 마인드', '유대인의 상술', '최애의 아이 16', '질문의 격', '2025 선재국어 최우선 실전 봉투 모의고사', '작별하지 않는다', '루리 드래곤 3', '2025 써니 행정법총론 봉투모의고사 (4회)']

# %%
# 책가격 1페이지 50개
price = soup.select('strong.txt_num>em.yes_b')
price_num = [round(float(p.text.replace(',',''))) for p in price]

# %%
# 가격에 원 붙히기
prices = price_num
prices_with_won = list(map(lambda x: str(x) + "원", prices))
prices_with_won
# Out:
# ['17010원',
#  '15750원',
#  '18000원',
#  '15120원',
#  '18000원',
#  '13500원',
#  '16020원',
#  '16020원',
#  '11700원',
#  '13500원',
#  '15750원',
#  '18900원',
#  '5400원',
#  '5400원',
#  '16200원',
#  '16020원',
#  '19800원',
#  '12600원',
#  '14220원',
#  '15300원',
#  '15120원',
#  '15300원',
#  '10800원',
#  '29700원',
#  '5400원',
#  '14220원',
#  '12960원',
#  '17820원',
#  '14850원',
#  '25200원',
#  '25020원',
#  '15120원',
#  '35100원',
#  '17820원',
#  '14400원',
#  '13500원',
#  '21420원',
#  '14220원',
#  '16200원',
#  '17100원',
#  '10800원',
#  '12600원',
#  '16650원',
#  '16920원',
#  '7110원',
#  '16020원',
#  '16200원',
#  '15120원',
#  '5400원',
#  '7200원']

# %%
for idx in range(len(title)):
    print("{} : {} - {}".format(idx+1,
                                  title[idx].text,
                                 prices_with_won[idx],
                                 ))
# Out:
# 1 : 청춘의 독서 - 17010원
# 2 : 엄마의 말 연습 - 15750원
# 3 : 어른의 품격을 채우는 100일 필사 노트 - 18000원
# 4 : 단 한 번의 삶 - 15120원
# 5 : 이로운 보수 의로운 진보 - 18000원
# 6 : 소년이 온다 - 13500원
# 7 : 어른의 행복은 조용하다 - 16020원
# 8 : 초역 부처의 말 - 16020원
# 9 : 모순 - 11700원
# 10 : 빛과 실 - 13500원
# 11 : 쇼펜하우어 인생수업 : 한 번뿐인 삶 이렇게 살아라 (리커버 에디션) - 15750원
# 12 : 듀얼 브레인 - 18900원
# 13 : 괴수 8호 15 트리플특장판 - 5400원
# 14 : 길고양이와 늑대 5 더블특전판 - 5400원
# 15 : 혼모노 - 16200원
# 16 : 위버멘쉬 - 16020원
# 17 : 결국 국민이 합니다 - 19800원
# 18 : 급류 - 12600원
# 19 : 에그박사 15 - 14220원
# 20 : 첫 여름, 완주 - 15300원
# 21 : 친구가 상처 줄 때 똑똑하게 나를 지키는 법 - 15120원
# 22 : 친구 사이에도 예의가 필요해 - 15300원
# 23 : 서랍에 저녁을 넣어 두었다 - 10800원
# 24 : 워런 버핏 웨이 - 29700원
# 25 : 봄의 폭풍과 몬스터 6 - 5400원
# 26 : 흔한남매 19 - 14220원
# 27 : 2025 심우철 실전 동형 모의고사 Season 4 - 12960원
# 28 : ETS 토익 정기시험 기출문제집 1000 Vol. 4 RC - 17820원
# 29 : 2025 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 상 - 14850원
# 30 : 엔비디아 젠슨 황, 생각하는 기계 - 25200원
# 31 : 넥서스 - 25020원
# 32 : 스토너 - 15120원
# 33 : 최애의 아이 16 특별판 - 35100원
# ...

# %%
result = []
for idx in range(len(title)):
    book_title = title[idx].text
    book_price = prices_with_won[idx]
    print(f"{idx+1} : {book_title} - {book_price}")    
    result.append([idx + 1, book_title, book_price])
# Out:
# 1 : 청춘의 독서 - 17010원
# 2 : 엄마의 말 연습 - 15750원
# 3 : 어른의 품격을 채우는 100일 필사 노트 - 18000원
# 4 : 단 한 번의 삶 - 15120원
# 5 : 이로운 보수 의로운 진보 - 18000원
# 6 : 소년이 온다 - 13500원
# 7 : 어른의 행복은 조용하다 - 16020원
# 8 : 초역 부처의 말 - 16020원
# 9 : 모순 - 11700원
# 10 : 빛과 실 - 13500원
# 11 : 쇼펜하우어 인생수업 : 한 번뿐인 삶 이렇게 살아라 (리커버 에디션) - 15750원
# 12 : 듀얼 브레인 - 18900원
# 13 : 괴수 8호 15 트리플특장판 - 5400원
# 14 : 길고양이와 늑대 5 더블특전판 - 5400원
# 15 : 혼모노 - 16200원
# 16 : 위버멘쉬 - 16020원
# 17 : 결국 국민이 합니다 - 19800원
# 18 : 급류 - 12600원
# 19 : 에그박사 15 - 14220원
# 20 : 첫 여름, 완주 - 15300원
# 21 : 친구가 상처 줄 때 똑똑하게 나를 지키는 법 - 15120원
# 22 : 친구 사이에도 예의가 필요해 - 15300원
# 23 : 서랍에 저녁을 넣어 두었다 - 10800원
# 24 : 워런 버핏 웨이 - 29700원
# 25 : 봄의 폭풍과 몬스터 6 - 5400원
# 26 : 흔한남매 19 - 14220원
# 27 : 2025 심우철 실전 동형 모의고사 Season 4 - 12960원
# 28 : ETS 토익 정기시험 기출문제집 1000 Vol. 4 RC - 17820원
# 29 : 2025 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 상 - 14850원
# 30 : 엔비디아 젠슨 황, 생각하는 기계 - 25200원
# 31 : 넥서스 - 25020원
# 32 : 스토너 - 15120원
# 33 : 최애의 아이 16 특별판 - 35100원
# ...

# %%
import pandas as pd
df = pd.DataFrame(result, columns=['no', 'title', 'price'])
df.head()
# Out:
#    no                   title   price
# 0   1                  청춘의 독서  17010원
# 1   2                엄마의 말 연습  15750원
# 2   3  어른의 품격을 채우는 100일 필사 노트  18000원
# 3   4                단 한 번의 삶  15120원
# 4   5           이로운 보수 의로운 진보  18000원

# %% [markdown]
# # 250529 웹크롤링연습

# %%
# 방법1
from requests import get
from bs4 import BeautifulSoup

url = 'https://www.yes24.com/product/category/bestseller?categoryNumber=001&pageNumber=1&pageSize=50'
# print(url)
response = get(url)
# response.status_code #200(정상) 상태확인
soup = BeautifulSoup(response.text, #response.content
                    'html.parser')
# soup
# Out:
# <!DOCTYPE html >
#
# <html lang="ko">
# <head><link <meta="" content="IE=Edge" href="https://m.yes24.com/Home/Best?DispNo=001" http-equiv="X-UA-Compatible" media="only screen and(max-width: 640px)" rel="alternate"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" http-equiv="Accept-CH"/>
# <meta content="86400" http-equiv="Accept-CH-Lifetime"/>
# <meta content="unsafe-url" name="referrer"/>
# <meta content="width=1170" name="viewport"/>
# <title> 국내도서 종합 베스트 - 예스24 </title>
# <meta content="예스24" name="title"/>
# <meta content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" name="description"/>
# <meta content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘, 리센스, 예스24 도서용품, 친환경 PB 브랜드, 사은품, 굿즈" name="keywords"/>
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

size = 50
pages = 3
items_list = []

for page in range(1, pages+1):
    url = f'https://www.yes24.com/product/category/bestseller?categoryNumber=001&pageNumber={page}&pageSize={size}'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # 크롤링 대상
    rank = soup.select('em.ico.rank')
    gd_img = soup.select('em.img_bdr > img.lazy')
    gd_name = soup.select('a.gd_name')    
    gd_nameE = soup.select('span.gd_nameE')
    writer = soup.select('span.authPub.info_auth > a')
    price = soup.select('strong.txt_num > em.yes_b')
    grade = soup.select('span.rating_grade > em.yes_b')

    # 책 개수만큼 반복 (보통 gd_name 기준)
    for i in range(len(gd_name)):
        items_list.append({
            'rank': rank[i].text.strip() if i < len(rank) else '',
            'title': gd_name[i].text.strip() if i < len(gd_name) else '',
            'subtitle': gd_nameE[i].text.strip() if i < len(gd_nameE) else '',
            'writer': writer[i].text.strip() if i < len(writer) else '',
            'price': price[i].text.strip() if i < len(price) else '',
            'grade': grade[i].text.strip() if i < len(grade) else '',
            'image': gd_img[i].get('data-original') if i < len(gd_img) and gd_img[i].has_attr('data-original') else '',
#             'link': gd_name[i].get('href') if i < len(gd_name) else ''
        })

# pandas DataFrame으로 변환
df = pd.DataFrame(items_list, columns=['rank', 'title', 'subtitle', 'writer', 'price', 'grade', 'image',]) #'link'

# 결과 출력
df
# Out:
#     rank                   title                             subtitle  \
# 0      1                  청춘의 독서                  세상을 바꾼 위험하고 위대한 생각들
# 1      2                엄마의 말 연습  화내지 않고 사랑하는 마음을 오롯이 전하는 39가지 존중어 수업
# 2      3                단 한 번의 삶               최강 형제가 들려주는 최소한의 정치 교양
# 3      4  어른의 품격을 채우는 100일 필사 노트                             양귀자 장편소설
# 4      5           이로운 보수 의로운 진보                    AI 시대의 실용적 생존 가이드
# ..   ...                     ...                                  ...
# 145  146                 장돌이네 떡집
# 146  147                     데미안
# 147  148               죽이고 싶은 아이
# 148  149              회복탄력성의 뇌과학
# 149  150                  평생 투자자
#
#       writer   price grade                                      image
# 0        유시민  17,010   9.5  https://image.yes24.com/goods/145629000/L
# 1        윤지영  15,750   9.8  https://image.yes24.com/goods/112925092/L
# 2        김영하  15,120   9.1  https://image.yes24.com/goods/144021119/L
# ...

# %%
df.to_csv('yes24_bestsellers.csv', index=False, encoding='cp949')

# %%
import pandas as pd

file_path = 'yes24_bestsellers.csv'

with open(file_path, 'r', encoding='utf-8') as f:
    df = pd.read_csv(f)

print(df.head())  # 앞부분만 출력
