# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font family: Consolas; font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family: Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding top:120px;}
div.text_cell_render ul li {font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font family: Consolas; font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family: Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding top:120px;}
# div.text_cell_render ul li {font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# <b><font color="red" size="5"> Untitled </font></b>

# %%
# 12분 08초
sum = 0
for i in range(1, 101):
    sum += i
print(sum)
# Out:
# 5050

# %%
import time

#시작시간 기록
for i in range(1000000):
    resurt = i ** 2
    
#종료시간 기록
end_time = time.time()

# %%
import timeit

def test_function():
    for i in range(1000000):
        result = i ** 2
        
#실행시간 측정
execution_time = timeit.timeit(test_function, number = 1)
print(f'코드 실행시간 : {execution_time:.6f}초')

# %%
import itertools

iterable1 = 'ABCD'
iterable2 = 'xy'
iterable3 = '1234'
print(list(itertools.product(iterable1, iterable2, iterable3)))
a = list(itertools.product(iterable1, iterable2, iterable3))

# %%
a.shape

# %%
import random
a=("백돈","엽떡")
print(random.choice(a))

# %%
a = int(input().strip())
b = int(input().strip())

print(f"a = {a}")
print(f"b = {b}")

# %% [markdown]
# # 웹크롤링

# %%
# 방법1 requests모듈
import requests
from bs4 import BeautifulSoup
url = 'https://www.yes24.com/product/category/bestseller?CategoryNumber=001&SumGb=02&pid=123487&cosemkid=go14913756400533498&utm_source=google_pc&utm_medium=cpc&utm_campaign=book_pc&utm_content=ys_240530_google_pc_cc_book_pc_yes24&utm_term=yes24%eb%b2%a0%ec%8a%a4%ed%8a%b8%ec%85%80%eb%9f%ac&gad_source=1&gad_campaignid=57752190&gbraid=0AAAAAD79Irpn6yOBw_-tFRQGS_7tiJXNW&gclid=Cj0KCQjwxdXBBhDEARIsAAUkP6hpmfi7gQxu34Pi8dR3GuIU986DS6fi_2Wsvno21Lv0itMmYtrQlBkaAteyEALw_wcB'
response = requests.get(url)
#response, response.status_code
#response.content
#response.content.decode('cp949')
#response.text
soup = BeautifulSoup(response.text, # response.content
                    'html.parser') #xml이면 xml.parser

# %%
# 책제목 1페이지 24개
title = soup.select('a.gd_name')
for t in title:
    print(t.text, end='\t')

# %%
# 책가격 1페이지 24개
price = soup.select('strong.txt_num>em.yes_b')
price_num = [round(float(p.text.replace(',',''))) for p in price]

# %%
# 가격에 원 붙히기
prices = price_num
prices_with_won = list(map(lambda x: str(x) + "원", prices))
prices_with_won

# %%
for idx in range(len(title)):
    print("{} : {} - {}".format(idx+1,
                                  title[idx].text,
                                 prices_with_won[idx],
                                 ))

# %%
result = []
for idx in range(len(title)):
    print("{} : {} - {}".format(idx+1,
                                  title[idx].text,
                                 prices_with_won[idx],
                                 ))
result

# %% [markdown]
# ## 2페이지

# %%
# 방법1 requests모듈
import requests
from bs4 import BeautifulSoup
url = 'https://www.yes24.com/product/category/bestseller?categoryNumber=001&pageNumber=2&pageSize=24'
response = requests.get(url)
#response, response.status_code
#response.content
#response.content.decode('cp949')
#response.text
soup2 = BeautifulSoup(response.text, # response.content
                    'html.parser') #xml이면 xml.parser

# %%
# 책제목 2페이지 24개
title2 = soup2.select('a.gd_name')
for t in title2:
    print(t.text, end='\t')

# %%
# 책가격 2페이지 24개
price2 = soup2.select('strong.txt_num>em.yes_b')
price_num2 = [round(float(p.text.replace(',',''))) for p in price2]

# %%
# 가격에 원 붙히기
prices2 = price_num2
prices_with_won2 = list(map(lambda x: str(x) + "원", prices2))
prices_with_won2

# %%
result2 = []
for idx in range(len(title2)):
    print("{} : {} - {}".format(idx+25,
                                  title2[idx].text,
                                 prices_with_won2[idx],
                                 ))
result2

# %%
result_append = result.append(result2)
print(result_append)

# %% [markdown]
# # 50개만 가져오기 (웹크롤링)

# %%
# 방법1 requests모듈
import requests
from bs4 import BeautifulSoup
url = 'https://www.yes24.com/product/category/bestseller?categoryNumber=001&pageNumber=1&pageSize=50'
response = requests.get(url)
soup = BeautifulSoup(response.text,
                    'html.parser')

# %%
# 책제목 1페이지 50개
titles = [t.text for t in soup.select('a.gd_name')]
print(titles)

# %%
# 책가격 1페이지 50개
price = soup.select('strong.txt_num>em.yes_b')
price_num = [round(float(p.text.replace(',',''))) for p in price]

# %%
# 가격에 원 붙히기
prices = price_num
prices_with_won = list(map(lambda x: str(x) + "원", prices))
prices_with_won

# %%
for idx in range(len(title)):
    print("{} : {} - {}".format(idx+1,
                                  title[idx].text,
                                 prices_with_won[idx],
                                 ))

# %%
result = []
for idx in range(len(title)):
    book_title = title[idx].text
    book_price = prices_with_won[idx]
    print(f"{idx+1} : {book_title} - {book_price}")    
    result.append([idx + 1, book_title, book_price])

# %%
import pandas as pd
df = pd.DataFrame(result, columns=['no', 'title', 'price'])
df.head()

# %% [markdown]
# # 250529 웹크롤링연습

# %%
# 방법1
from requests import get
from bs4 import BeautifulSoup

url = 'https://www.yes24.com/product/category/bestseller?categoryNumber=001&pageNumber=1&pageSize=50'
# print(url)
response = get(url)
# response.status_code #200(정상) 상태확인
soup = BeautifulSoup(response.text, #response.content
                    'html.parser')
# soup

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

size = 50
pages = 3
items_list = []

for page in range(1, pages+1):
    url = f'https://www.yes24.com/product/category/bestseller?categoryNumber=001&pageNumber={page}&pageSize={size}'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # 크롤링 대상
    rank = soup.select('em.ico.rank')
    gd_img = soup.select('em.img_bdr > img.lazy')
    gd_name = soup.select('a.gd_name')    
    gd_nameE = soup.select('span.gd_nameE')
    writer = soup.select('span.authPub.info_auth > a')
    price = soup.select('strong.txt_num > em.yes_b')
    grade = soup.select('span.rating_grade > em.yes_b')

    # 책 개수만큼 반복 (보통 gd_name 기준)
    for i in range(len(gd_name)):
        items_list.append({
            'rank': rank[i].text.strip() if i < len(rank) else '',
            'title': gd_name[i].text.strip() if i < len(gd_name) else '',
            'subtitle': gd_nameE[i].text.strip() if i < len(gd_nameE) else '',
            'writer': writer[i].text.strip() if i < len(writer) else '',
            'price': price[i].text.strip() if i < len(price) else '',
            'grade': grade[i].text.strip() if i < len(grade) else '',
            'image': gd_img[i].get('data-original') if i < len(gd_img) and gd_img[i].has_attr('data-original') else '',
#             'link': gd_name[i].get('href') if i < len(gd_name) else ''
        })

# pandas DataFrame으로 변환
df = pd.DataFrame(items_list, columns=['rank', 'title', 'subtitle', 'writer', 'price', 'grade', 'image',]) #'link'

# 결과 출력
df

# %%
df.to_csv('yes24_bestsellers.csv', index=False, encoding='cp949')

# %%
import pandas as pd

file_path = 'yes24_bestsellers.csv'

with open(file_path, 'r', encoding='utf-8') as f:
    df = pd.read_csv(f)

print(df.head())  # 앞부분만 출력

# %%
import pandas as pd

# 원래 하나의 딕셔너리
list_a = {
    '인터넷 서비스 제공업체': 'SK Broadband',
    '호스트 이름': '-',
    '국가': 'South Korea',
    '지역/도': 'Gyenggi-do',
    '도시': 'Yongin-si',
    '우편번호': 169,
}

# 같은 내용을 여러 번 리스트에 추가
list_b = []
for i in range(3):  # 예시로 3번 반복
    list_b.append({
        '인터넷 서비스 제공업체': 'SK Broadband',
        '호스트 이름': '-',
        '국가': 'South Korea',
        '지역/도': 'Gyenggi-do',
        '도시': 'Yongin-si',
        '우편번호': 169,
    })

# DataFrame 생성
df = pd.DataFrame(list_b)

# 결과 출력
print(df)

# %%
import pandas as pd

# 딕셔너리 선언
list_a = {
    '인터넷 서비스 제공업체': 'SK Broadband',
    '호스트 이름': '-',
    '국가': 'South Korea',
    '지역/도': 'Gyenggi-do',
    '도시': 'Yongin-si',
    '우편번호': 169,
}

# 1줄짜리 DataFrame 생성
df = pd.DataFrame([list_a])

# 출력 (확인용)
print(df)

# CSV로 저장
df.to_csv('data.csv', index=False, encoding='cp949')

# %%
import pandas as pd

# JSON 데이터 (예시 일부, 실제 사용할 때는 전체 JSON을 사용하세요)
data = {
    "startAddress": "61.254.160.0",
    "endAddress": "61.255.255.255",
    "handle": "61.254.160.0 - 61.255.255.255",
    "country": "KR",
    "name": "broadNnet-KR",
    "remarks": [{"description": ["SK Broadband Co Ltd"]}],
    "entities": [
        {
            "roles": ["technical", "administrative"],
            "vcardArray": [
                "vcard",
                [
                    ["version", {}, "text", "4.0"],
                    ["fn", {}, "text", "IP Manager"],
                    ["kind", {}, "text", "individual"],
                    ["adr", {"label": "Seoul Jung-gu Toegye-ro 24\nSK Namsan Green Bldg."}, "text", ["", "", "", "", "", "", ""]],
                    ["tel", {"type": "voice"}, "text", "+82-80-828-2106"],
                    ["email", {}, "text", "ip-adm@skbroadband.com"]
                ]
            ],
        },
        {
            "roles": ["abuse"],
            "vcardArray": [
                "vcard",
                [
                    ["version", {}, "text", "4.0"],
                    ["fn", {}, "text", "IRT-KRNIC-KR"],
                    ["kind", {}, "text", "group"],
                    ["adr", {"label": "Seocho-ro 398, Seocho-gu, Seoul, Korea"}, "text", ["", "", "", "", "", "", ""]],
                    ["email", {}, "text", "hostmaster@nic.or.kr"]
                ]
            ],
        }
    ]
}

# 정보 추출
row = {
    "ISP 이름": data.get("name"),
    "ISP 설명": data.get("remarks", [{}])[0].get("description", [""])[0],
    "국가": data.get("country"),
    "IP 범위": data.get("handle"),
    "시작 IP": data.get("startAddress"),
    "종료 IP": data.get("endAddress"),
    "관리자 이름": data["entities"][0]["vcardArray"][1][1][3],
    "주소": data["entities"][0]["vcardArray"][1][3][1].get("label", ""),
    "전화번호": data["entities"][0]["vcardArray"][1][4][3],
    "이메일": data["entities"][0]["vcardArray"][1][5][3],
    "Abuse 이메일": data["entities"][1]["vcardArray"][1][4][3],
}

# DataFrame 생성 및 CSV 저장
df = pd.DataFrame([row])
df.to_csv("rdap_info.csv", index=False, encoding='utf-8-sig')

print(df)

# %%
import pandas as pd

# 데이터 정리
ip_info = {
    "IP 주소": "61.254.199.139",
    "도시": "Haegok",
    "지역": "Gyeonggi-do",
    "국가": "South Korea",
    "우편번호": "17142",
    "위도": 37.1925,
    "경도": 127.2788,
    "ASN": "AS9318",
    "ISP 이름": "SK Broadband Co Ltd",
    "ASN 유형": "ISP",
    "도메인": "skbroadband.com",
    "IP 범위": "61.254.192.0/18",
    "abuse 주소": "9, Jinheung-gil, Naju-si, Jeollanam-do",
    "abuse 전화번호": "+82-80-828-2106",
    "abuse 이메일": "irt@nic.or.kr",
    "담당자 이름": "IP Manager",
    "전체 네트워크 범위": "61.254.160.0-61.255.255.255",
}

# DataFrame 생성
df = pd.DataFrame([ip_info])

# CSV로 저장
df.to_csv("ipinfo제공_data.csv", index=False, encoding='utf-8-sig')

# 확인용 출력
print(df)

# %%
import folium

# 위도와 경도
latitude = 37.1925
longitude = 127.2788

# 지도 객체 생성
m = folium.Map(location=[latitude, longitude], zoom_start=12)

# 마커 추가
tooltip_text = "사칭범IP주소 / 서울,용인시 / 우편번호 17142 / 위도 37.1924, 경도 127.2788 / 61.254.199.139"
folium.Marker(
    location=[latitude, longitude],
    popup=tooltip_text,
    tooltip=tooltip_text,
    icon=folium.Icon(color="blue", icon="info-sign")
).add_to(m)

# HTML로 저장
m.save("ip_location_map.html")

print("지도가 ip_location_map.html로 저장되었습니다.")

# %% [markdown]
# # 영어번역 자동화 프로그램 (동적 웹크롤링)
# - 1500자
# - 제출 파일 : 2_본인이름소스.ipynb, 2_실행결과및소스.html, 2_한글원본.txt, 2_자동화영어번역본.txt

# %%
# 한셀로 합치기
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd

driver = webdriver.Chrome()
driver.get('https://translate.kakao.com/')

time.sleep(1)

# input 태그를 click
driver.find_element(By.ID, 'textareaWrite').click()
query = input('번역하고자 하는 한글은?')
driver.find_element(By.CSS_SELECTOR, 'input[type="text"]').send_keys(query)
driver.find_element(By.CLASS_NAME, 'btn_ksearch').click()

time.sleep(3)

driver.find_element(By.LINK_TEXT, '번역하기').click()

time.sleep(3)





news_list = []

pages = 3
for page in range(1, pages+1):
    elems = driver.find_elements(By.CSS_SELECTOR, 'div.item-title > strong.tit-g.clamp-g > a')
    for elem in elems:
        title = elem.text
        link = elem.get_attribute('href')
        news_list.append(['title','link'])
#         print(title,link)
    # 2page로
    page_div = driver.find_element(By.CSS_SELECTOR, 'div.inner_paging')
    # print(page_div.text)
    next_page = page_div.find_element(By.LINK_TEXT, str(page+1))
    next_page.click()
    
    time.sleep(1.5)
    
    print(f'~ ~ 현재 {page}페이지 데이터 수집 중입니다 ~ ~')
driver.close()

# %%
df = pd.DataFrame(news_list, columns=['title','link'])
df.to_csv('data/ch14_daum.csv', index=False, encoding='cp949')

# %% [markdown]
# # 동적크롤링 예제 2

# %% [markdown]
# #### 맞춤법 전->후

# %%
# ch14_맞춤법전.txt를 300자이내로 자르기
with open('data/ch14_맞춤법전.txt', 'r', encoding='utf-8') as f:
    text = f.read()
print('총글자 수 :',len(text))
ready_list = [] # 맞춤법 검사할 text 내용(300이자 이내로 list)
while(len(text) > 300):
    temp = text[:300]
    new_line_char_index = temp.rfind('\n')
    print(new_line_char_index)
    ready_list.append(text[:new_line_char_index])
    text = text[new_line_char_index:]
ready_list.append(text)
[ready[:10] for ready in ready_list]

# %%
# 네이버 맞춤법 py파일로
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time
import pandas as pd

driver = webdriver.Chrome()

time.sleep(0.5)

driver.get('https://www.naver.com/')
input_elem = driver.find_element(By.CSS_SELECTOR, 'input[name="query"]')
input_elem.send_keys('맞춤법 검사기')
input_elem.send_keys(Keys.RETURN)

time.sleep(0.5)

results = '' # 맞춤법 검사 후 내용

textarea = driver.find_element(By.CLASS_NAME, 'txt_gray')

for ready in ready_list:
    time.sleep(2)
    
    textarea.send_keys(Keys.CONTROL, 'a') # control + a
    textarea.send_keys(ready)

    button = driver.find_element(By.CLASS_NAME, 'btn_check')
    button.click()

    time.sleep(2)

    soup = BeautifulSoup(driver.page_source, "html.parser")
    result = soup.select_one('p._result_text.stand_txt').text
    results += result + '\n\n'
    
driver.close()

with open('data/ch14_맞춤법후_한글원본.txt', 'w', encoding='utf-8') as f:
    f.write(results)

# %% [markdown]
# #### 네이버 맞춤법후 파일을 다음 번역기로 번역

# %%
# ch14_맞춤법후.txt를 300자이내로 자르기
with open('data/ch14_맞춤법후_한글원본.txt', 'r', encoding='utf-8') as f:
    text = f.read()
print('총글자 수 :',len(text))
ready_list = [] # 다음에서 번역할 text 내용(300이자 이내로 list)
while(len(text) > 300):
    temp = text[:300]
    new_line_char_index = temp.rfind('\n')
    print(new_line_char_index)
    ready_list.append(text[:new_line_char_index])
    text = text[new_line_char_index:]
ready_list.append(text)
[ready[:10] for ready in ready_list]

# %%
# 다음에서 번역
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time
import pandas as pd

driver = webdriver.Chrome()

time.sleep(0.5)

driver.get('https://www.daum.net/')
input_elem = driver.find_element(By.NAME, 'q')
input_elem.send_keys('다음 번역기')
input_elem.send_keys(Keys.RETURN)

time.sleep(0.5)

results = '' # 번역 후 내용

textarea = driver.find_element(By.ID, 'textareaWrite')

for ready in ready_list:
    time.sleep(2)
    
    textarea.send_keys(Keys.CONTROL, 'a') # control + a
    textarea.send_keys(ready)

    button = driver.find_element(By.LINK_TEXT, '번역하기')
    button.click()

    time.sleep(2)

    soup = BeautifulSoup(driver.page_source, "html.parser")
    result = soup.select_one('div#resultRender > div.result_area.area_item.txt_eng.translate_many').text
    results += result + '\n\n'
    
driver.close()

with open('data/ch14_자동화영어번역본.txt', 'w', encoding='utf-8') as f:
    f.write(results)

# %% [markdown]
# # 로또번호 추출기

# %%
import numpy as np

for i in range(10):
    lotto = np.random.choice(np.arange(1, 46), 7, replace=False)
    main, bonus = np.sort(lotto[:6]), lotto[6]
    print(f"{i+1:2}회차 → 당첨 번호: {main} / 보너스: {bonus}")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import sys

def get_lotto_numbers(draw_no):
    try:
        url = f"https://www.dhlottery.co.kr/gameResult.do?method=byWin&drwNo={draw_no}"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0 Safari/537.36"
        }
        res = requests.get(url, headers=headers, timeout=10)
        soup = BeautifulSoup(res.text, "html.parser")

        win_nums = soup.select(".win_result .nums span.ball_645")
        bonus_num = soup.select_one(".win_result .bonus span.ball_645")

        if len(win_nums) < 6 or bonus_num is None:
            print(f"[{draw_no}회] 데이터 부족. 건너뜀.")
            return None

        win_nums = [int(num.text) for num in win_nums]
        bonus = int(bonus_num.text)

        return {
            "회차": draw_no,
            "번호1": win_nums[0],
            "번호2": win_nums[1],
            "번호3": win_nums[2],
            "번호4": win_nums[3],
            "번호5": win_nums[4],
            "번호6": win_nums[5],
            "보너스": bonus
        }

    except Exception as e:
        print(f"[{draw_no}회] 오류 발생: {e}")
        return "error"

all_data = []
fail_list = []

total = 1174

for i in range(1, total + 1):
    result = get_lotto_numbers(i)
    if result == "error":
        fail_list.append(i)
    elif result:
        all_data.append(result)

    progress = (i / total) * 100
    sys.stdout.write(f"\r진행률: {progress:.1f}% ({i} / {total})")
    sys.stdout.flush()

    time.sleep(0.5)

print("\n⏳ 1차 완료. 오류 회차 수: {}개. 재시도 중...".format(len(fail_list)))

retry_list = []
for i in fail_list:
    time.sleep(1)
    result = get_lotto_numbers(i)
    if result == "error":
        retry_list.append(i)
    elif result:
        all_data.append(result)

print(f" 최종 완료! 실패한 회차 수: {len(retry_list)}개")

df = pd.DataFrame(all_data)
df = df.sort_values("회차")
df.to_csv("lotto_numbers.csv", index=False, encoding='utf-8-sig')
print("💾 로또 데이터 저장 완료!")

if retry_list:
    print("다시 시도해도 실패한 회차:", retry_list)
# Out:
# --------------------------------
# ValueErrorTraceback (most recent call last)
# Cell In[8], line 3
#       1 import requests
#       2 from bs4 import BeautifulSoup
# ----> 3 import pandas as pd
#       4 import time
#       5 import sys
#
# File ~\anaconda3\lib\site-packages\pandas\__init__.py:46
#      43 # let init-time option registration happen
#      44 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 46 from pandas.core.api import (
#      47     # dtype
#      48     ArrowDtype,
#      49     Int8Dtype,
#      50     Int16Dtype,
#      51     Int32Dtype,
#      52     Int64Dtype,
#      53     UInt8Dtype,
#      54     UInt16Dtype,
#      55     UInt32Dtype,
#      56     UInt64Dtype,
#      57     Float32Dtype,
#      58     Float64Dtype,
#      59     CategoricalDtype,
#      60     PeriodDtype,
#      61     IntervalDtype,
#      62     DatetimeTZDtype,
#      63     StringDtype,
#      64     BooleanDtype,
#      65     # missing
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import sys
import os

def get_latest_draw_no():
    url = "https://www.dhlottery.co.kr/gameResult.do?method=byWin"
    headers = {
        "User-Agent": "Mozilla/5.0"
    }
    res = requests.get(url, headers=headers, timeout=10)
    soup = BeautifulSoup(res.text, "html.parser")
    # 최신 회차 번호가 들어있는 태그 선택
    latest_no_tag = soup.select_one(".nums > strong")
    if latest_no_tag:
        return int(latest_no_tag.text.strip())
    else:
        return None

def get_lotto_numbers(draw_no):
    try:
        url = f"https://www.dhlottery.co.kr/gameResult.do?method=byWin&drwNo={draw_no}"
        headers = {
            "User-Agent": "Mozilla/5.0"
        }
        res = requests.get(url, headers=headers, timeout=10)
        soup = BeautifulSoup(res.text, "html.parser")

        win_nums = soup.select(".win_result .nums span.ball_645")
        bonus_num = soup.select_one(".win_result .bonus span.ball_645")

        if len(win_nums) < 6 or bonus_num is None:
            print(f"[{draw_no}회] 데이터 부족. 건너뜀.")
            return None

        win_nums = [int(num.text) for num in win_nums]
        bonus = int(bonus_num.text)

        return {
            "회차": draw_no,
            "번호1": win_nums[0],
            "번호2": win_nums[1],
            "번호3": win_nums[2],
            "번호4": win_nums[3],
            "번호5": win_nums[4],
            "번호6": win_nums[5],
            "보너스": bonus
        }

    except Exception as e:
        print(f"[{draw_no}회] 오류 발생: {e}")
        return "error"

# 저장된 데이터가 있으면 불러오기
csv_path = "lotto_numbers.csv"
if os.path.exists(csv_path):
    df_existing = pd.read_csv(csv_path)
    start_no = df_existing["회차"].max() + 1
else:
    df_existing = pd.DataFrame()
    start_no = 1

# 최신 회차 가져오기
latest_no = get_latest_draw_no()
if latest_no is None:
    print("최신 회차를 가져오지 못했습니다. 수동으로 total 지정 필요.")
    total = 1174  # 수동 지정 가능
else:
    total = latest_no

print(f"크롤링 시작: {start_no}회부터 {total}회까지")

all_data = []

fail_list = []

for i in range(start_no, total + 1):
    result = get_lotto_numbers(i)
    if result == "error":
        fail_list.append(i)
    elif result:
        all_data.append(result)

    progress = (i - start_no + 1) / (total - start_no + 1) * 100
    sys.stdout.write(f"\r진행률: {progress:.1f}% ({i} / {total})")
    sys.stdout.flush()

    time.sleep(0.5)

print("\n⏳ 1차 완료. 오류 회차 수: {}개. 재시도 중...".format(len(fail_list)))

retry_list = []
for i in fail_list:
    time.sleep(1)
    result = get_lotto_numbers(i)
    if result == "error":
        retry_list.append(i)
    elif result:
        all_data.append(result)

print(f" 최종 완료! 실패한 회차 수: {len(retry_list)}개")

# 기존 데이터랑 합치기
if not df_existing.empty:
    df_new = pd.DataFrame(all_data)
    df_all = pd.concat([df_existing, df_new], ignore_index=True)
    df_all = df_all.drop_duplicates(subset="회차").sort_values("회차")
else:
    df_all = pd.DataFrame(all_data)

df_all.to_csv(csv_path, index=False, encoding='utf-8-sig')
print("💾 로또 데이터 저장 완료!")

if retry_list:
    print("다시 시도해도 실패한 회차:", retry_list)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (2.4.0) or chardet (4.0.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn(
# 최신 회차를 가져오지 못했습니다. 수동으로 total 지정 필요.
# 크롤링 시작: 1175회부터 1174회까지
#
# ⏳ 1차 완료. 오류 회차 수: 0개. 재시도 중...
#  최종 완료! 실패한 회차 수: 0개
# 💾 로또 데이터 저장 완료!

# %% [markdown]
# ## 1. 데이터 전처리

# %%
import pandas as pd
import numpy as np

# 데이터 불러오기
df = pd.read_csv("lotto_numbers.csv")

# 번호들 one-hot encoding 함수 (1~45 숫자 각각 0/1로 표시)
def one_hot(row):
    arr = np.zeros(45, dtype=int)
    numbers = row[['번호1','번호2','번호3','번호4','번호5','번호6']].values
    for n in numbers:
        arr[n-1] = 1
    return arr

X = []
Y = []

# 한 회차의 번호로 다음 회차 번호 예측하도록 데이터 생성
for i in range(len(df)-1):
    X.append(one_hot(df.iloc[i]))
    Y.append(one_hot(df.iloc[i+1]))

X = np.array(X)
Y = np.array(Y)

print("X shape:", X.shape)  # (데이터수, 45)
print("Y shape:", Y.shape)
# Out:
# X shape: (1173, 45)
# Y shape: (1173, 45)

# %% [markdown]
# ## 2. 모델 만들기 (Keras)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# 데이터 준비(X, Y는 네 데이터셋)
X_train, X_val, Y_train, Y_val = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

model = Sequential()
model.add(Dense(256, input_dim=X.shape[1], activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dense(Y.shape[1], activation='sigmoid'))  # 멀티라벨용 시그모이드

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train, Y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val, Y_val),
    callbacks=[early_stop]
)
# Out:
# -----------------------------
# ImportErrorTraceback (most recent call last)
# File ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: DLL 초기화 루틴을 실행할 수 없습니다.
#
# During handling of the above exception, another exception occurred:
#
# ImportErrorTraceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from tensorflow.keras.models import Sequential
# ...

# %% [markdown]
# ## 4. 예측 (예시)

# %%
pred = model.predict(X[-1].reshape(1,-1))[0]  # 마지막 데이터를 입력으로

# 0.5 이상인 숫자 추출 (예측된 번호)
predicted_numbers = [i+1 for i, p in enumerate(pred) if p > 0.5]

print("예측된 번호들:", predicted_numbers)
