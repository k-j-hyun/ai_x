# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:100% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:20pt;}
div.text_cell_render.rendered_html{font-size:18pt;}
div.text_cell_render.rendered_html{font-size:15pt;}
div.output {font-size:18pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:18pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:18pt;padding:5px;}
table.dataframe{font-size:18px;}
</style>
"""))
# Out:
# <style>
# div.container{width:100% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:20pt;}
# div.text_cell_render.rendered_html{font-size:18pt;}
# div.text_cell_render.rendered_html{font-size:15pt;}
# div.output {font-size:18pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:18pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:18pt;padding:5px;}
# table.dataframe{font-size:18px;}
# </style>

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.datasets import mnist # mnist 훈련셋과 테스트셋
from tensorflow.keras.utils import to_categorical # 원핫인코딩
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout
from matplotlib import pyplot as plt # 학습과정 loss와 acc 시각화

# %%
# 1. 데이터 셋
width = 28; height=28
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
plt_row = 3
plt_col = 10
# plt.figure(figsize=(plt_col, plt_row))
plt.rcParams['figure.figsize'] = [plt_col, plt_row]
plt.rc("font", family="Malgun Gothic") # window에서 한글 시각화
# plt.rc("font", family="NanumBarunGothic") # 코랩에서 한글 시각화
fig, axes = plt.subplots(plt_row, plt_col)

# axes[0, 0].imshow(X_test[0].reshape(width, height))
# axes[0, 0].axis('off')
# title = "실제;{}".format(y_test[0])
# axes[0, 0].set_title(title)

for i in range(plt_row*plt_col):
    subax = axes[i//plt_col, i%plt_col] # //:몫연산자 %:나머지연산자
    subax.imshow(X_test[i].reshape(width, height))
    subax.axis('off')
    title = "실제:{}".format(y_test[i])
    subax.set_title(title)
plt.tight_layout()

# %% [markdown]
# # 1. DNN

# %%
# import
import numpy as np
import seaborn as sns # statsmodel, sklearn 등에서 가져올 수 있음 iris데이터
import pandas as pd # 원핫인코딩 pd.get_dummies
from sklearn.preprocessing import LabelEncoder # 라벨인코딩(문자->숫자)
from tensorflow.keras.utils import to_categorical # 원핫인코딩
from sklearn.model_selection import train_test_split # 데이터분할(층화추출)
from tensorflow.keras.models import Sequential, load_model, save_model
from tensorflow.keras.layers import Dense, Input, Dropout, add
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt # 학습과정 시각화

# %%
# %%time
#1. 데이터 생성 및 전처리
width = 28; height = 28
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_val = X_train[50000:]
y_val = y_train[50000:]
X_train = X_train[:50000]
y_train = y_train[:50000]
# 독립변수 (28,28) => 784 1차원 -> 실수형변환 -> 스케일조정
X_train = X_train.reshape(-1, width*height).astype(np.float32)/255.0
X_val = X_val.reshape(-1, width*height).astype(np.float32)/255.0
X_test = X_test.reshape(-1, width*height).astype(np.float32)/255.0
# 타겟변수 원핫인코딩
Y_train = to_categorical(y_train)
Y_val = to_categorical(y_val)
Y_test = to_categorical(y_test)

X_train.shape, Y_train.shape, X_val.shape, Y_val.shape, X_test.shape, Y_test.shape

# 2. 모델 구성
model = Sequential([
    Input(shape=(width*height,)),
    Dense(1024, activation='relu'),
    Dropout(0.3),
    Dense(512, activation='relu'),
    Dropout(0.3),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])
# model.summary()

# 3. 학습설정
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 4. 학습
model.fit(X_train, Y_train,
         epochs=50,
         validation_data=(X_val, Y_val),
         verbose=1)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.2701 - accuracy: 0.9166 - val_loss: 0.1307 - val_accuracy: 0.9619
# Epoch 2/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.1421 - accuracy: 0.9587 - val_loss: 0.0941 - val_accuracy: 0.9718
# Epoch 3/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.1119 - accuracy: 0.9671 - val_loss: 0.0939 - val_accuracy: 0.9733
# Epoch 4/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0943 - accuracy: 0.9723 - val_loss: 0.0842 - val_accuracy: 0.9770
# Epoch 5/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.0824 - accuracy: 0.9746 - val_loss: 0.1112 - val_accuracy: 0.9733
# Epoch 6/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.0742 - accuracy: 0.9793 - val_loss: 0.0997 - val_accuracy: 0.9768
# Epoch 7/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0701 - accuracy: 0.9796 - val_loss: 0.0987 - val_accuracy: 0.9773
# Epoch 8/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.0662 - accuracy: 0.9810 - val_loss: 0.0778 - val_accuracy: 0.9802
# Epoch 9/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.0587 - accuracy: 0.9832 - val_loss: 0.0986 - val_accuracy: 0.9777
# Epoch 10/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.0588 - accuracy: 0.9839 - val_loss: 0.0823 - val_accuracy: 0.9807
# Epoch 11/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.0572 - accuracy: 0.9837 - val_loss: 0.0930 - val_accuracy: 0.9792
# Epoch 12/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0531 - accuracy: 0.9850 - val_loss: 0.0906 - val_accuracy: 0.9790
# Epoch 13/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0507 - accuracy: 0.9859 - val_loss: 0.1082 - val_accuracy: 0.9788
# Epoch 14/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0448 - accuracy: 0.9869 - val_loss: 0.0954 - val_accuracy: 0.9817
# Epoch 15/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0450 - accuracy: 0.9872 - val_loss: 0.1052 - val_accuracy: 0.9809
# Epoch 16/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0461 - accuracy: 0.9876 - val_loss: 0.1126 - val_accuracy: 0.9792
# Epoch 17/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0436 - accuracy: 0.9885 - val_loss: 0.1061 - val_accuracy: 0.9781
# Epoch 18/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0442 - accuracy: 0.9882 - val_loss: 0.1120 - val_accuracy: 0.9808
# Epoch 19/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0388 - accuracy: 0.9894 - val_loss: 0.1066 - val_accuracy: 0.9806
# Epoch 20/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0407 - accuracy: 0.9889 - val_loss: 0.1131 - val_accuracy: 0.9805
# Epoch 21/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0448 - accuracy: 0.9893 - val_loss: 0.1152 - val_accuracy: 0.9824
# Epoch 22/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.0409 - accuracy: 0.9895 - val_loss: 0.0888 - val_accuracy: 0.9825
# Epoch 23/50
# 1563/1563 [==============================] - 23s 14ms/step - loss: 0.0390 - accuracy: 0.9898 - val_loss: 0.1294 - val_accuracy: 0.9814
# Epoch 24/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0403 - accuracy: 0.9903 - val_loss: 0.1150 - val_accuracy: 0.9813
# Epoch 25/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.0363 - accuracy: 0.9908 - val_loss: 0.1153 - val_accuracy: 0.9817
# Epoch 26/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0427 - accuracy: 0.9901 - val_loss: 0.1125 - val_accuracy: 0.9826
# Epoch 27/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0339 - accuracy: 0.9909 - val_loss: 0.1288 - val_accuracy: 0.9812
# Epoch 28/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0443 - accuracy: 0.9906 - val_loss: 0.1255 - val_accuracy: 0.9818
# Epoch 29/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0327 - accuracy: 0.9918 - val_loss: 0.1428 - val_accuracy: 0.9842
# Epoch 30/50
# 1563/1563 [==============================] - 23s 14ms/step - loss: 0.0414 - accuracy: 0.9902 - val_loss: 0.1376 - val_accuracy: 0.9819
# Epoch 31/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0372 - accuracy: 0.9913 - val_loss: 0.1296 - val_accuracy: 0.9812
# Epoch 32/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0312 - accuracy: 0.9929 - val_loss: 0.1305 - val_accuracy: 0.9806
# Epoch 33/50
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.0366 - accuracy: 0.9921 - val_loss: 0.1158 - val_accuracy: 0.9815
# Epoch 34/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.0310 - accuracy: 0.9928 - val_loss: 0.1594 - val_accuracy: 0.9812
# Epoch 35/50
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.0369 - accuracy: 0.9921 - val_loss: 0.1336 - val_accuracy: 0.9837
# Epoch 36/50
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.0378 - accuracy: 0.9919 - val_loss: 0.1340 - val_accuracy: 0.9823
# Epoch 37/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0387 - accuracy: 0.9914 - val_loss: 0.1363 - val_accuracy: 0.9819
# Epoch 38/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0334 - accuracy: 0.9921 - val_loss: 0.1416 - val_accuracy: 0.9842
# Epoch 39/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0331 - accuracy: 0.9925 - val_loss: 0.1316 - val_accuracy: 0.9839
# Epoch 40/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0320 - accuracy: 0.9928 - val_loss: 0.1509 - val_accuracy: 0.9834
# Epoch 41/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0436 - accuracy: 0.9913 - val_loss: 0.1619 - val_accuracy: 0.9822
# Epoch 42/50
# 1563/1563 [==============================] - 23s 14ms/step - loss: 0.0412 - accuracy: 0.9920 - val_loss: 0.1487 - val_accuracy: 0.9799
# Epoch 43/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0326 - accuracy: 0.9931 - val_loss: 0.1584 - val_accuracy: 0.9838
# Epoch 44/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0342 - accuracy: 0.9924 - val_loss: 0.1652 - val_accuracy: 0.9800
# Epoch 45/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0337 - accuracy: 0.9923 - val_loss: 0.1653 - val_accuracy: 0.9835
# Epoch 46/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0291 - accuracy: 0.9936 - val_loss: 0.1766 - val_accuracy: 0.9812
# Epoch 47/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0337 - accuracy: 0.9929 - val_loss: 0.1576 - val_accuracy: 0.9832
# Epoch 48/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0374 - accuracy: 0.9925 - val_loss: 0.1354 - val_accuracy: 0.9832
# Epoch 49/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0326 - accuracy: 0.9931 - val_loss: 0.1602 - val_accuracy: 0.9817
# Epoch 50/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0366 - accuracy: 0.9933 - val_loss: 0.1633 - val_accuracy: 0.9817
# CPU times: total: 1h 16min 51s
# Wall time: 18min 29s

# %%
model.save('mnist_dnn.h5')

# %%
model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1503 - accuracy: 0.9826
# [0.1502779871225357, 0.9825999736785889]

# %%
# 혼동행렬
from sklearn.metrics import confusion_matrix
print('실제값 :', y_test)
print('실제값 :', np.argmax(Y_test, axis=1))
yhat = model.predict(X_test).argmax(axis=1)
cmatrix = confusion_matrix(y_test, yhat)
cmatrix
# Out:
# 실제값 : [7 2 1 ... 4 5 6]
# 실제값 : [7 2 1 ... 4 5 6]
# 313/313 [==============================] - 1s 4ms/step
# array([[ 972,    1,    0,    0,    1,    1,    3,    1,    0,    1],
#        [   0, 1131,    0,    0,    0,    0,    1,    0,    3,    0],
#        [   1,    0, 1017,    1,    2,    0,    2,    4,    5,    0],
#        [   0,    0,    3,  996,    0,    2,    0,    4,    2,    3],
#        [   2,    1,    1,    0,  965,    0,    6,    1,    0,    6],
#        [   2,    0,    0,    8,    1,  876,    4,    0,    0,    1],
#        [   2,    2,    0,    0,    3,    2,  949,    0,    0,    0],
#        [   0,    6,    6,    1,    2,    0,    0, 1005,    4,    4],
#        [   3,    2,    0,   11,    4,    9,    3,    3,  936,    3],
#        [   1,    2,    0,    2,   11,    4,    1,    2,    7,  979]],
#       dtype=int64)

# %% [markdown]
# ### 실제값과 예측값이 다른 갯수(방법1)

# %%
# 실제값과 예측값이 다른 갯수(방법1)
cnt = 0
for i, row in enumerate(cmatrix):
    for j, data in enumerate(row):
        if i!=j:
            cnt += data
print('예측이 틀린 갯수 :', cnt)
# Out:
# 예측이 틀린 갯수 : 174

# %% [markdown]
# ### 실제값과 예측값이 다른 갯수(방법2)

# %%
# 실제값과 예측값이 다른 갯수(방법2)
cnt = 0
for y, h in zip(y_test, yhat):
    if y != h:
        cnt += 1
print('예측이 틀린 갯수 :', cnt)
# Out:
# 예측이 틀린 갯수 : 174

# %% [markdown]
# ### CNN을 사용하여 예측이 틀린 데이터 출력(yhat과 y_test가 다른 것들 172개)

# %%
# CNN을 사용하여 예측이 틀린 데이터 출력(yhat과 y_test가 다른 것들 172개)
plt_row = 18
plt_col = 10
# plt.figure(figsize=(plt_col, plt_row))
plt.rcParams['figure.figsize'] = [plt_col, plt_row]
plt.rc("font", family="Malgun Gothic") # window에서 한글 시각화
# plt.rc("font", family="NanumBarunGothic") # 코랩에서 한글 시각화
fig, axes = plt.subplots(plt_row, plt_col)

plt.subplots_adjust(hspace=0.4, wspace=0.3)

i = 0 # yhat과 y_test의 index => yhat[i], y_test[i]를 비교
cnt = 0 # 이미지 출력횟수

while (i<len(y_test)) & (cnt < plt_row*plt_col):
    if yhat[i] == y_test[i]:
        i += 1
        continue
    subax = axes[cnt//plt_col, cnt%plt_col] # //:몫연산자 %:나머지연산자
    subax.imshow(X_test[i].reshape(width, height))
    subax.axis('off')
    title = "y:{},h:{},({})".format(y_test[i],yhat[i],i)
    subax.set_title(title)
    cnt += 1 # 이미지 출력 번호 증가
    i += 1 # index 번호 증가
plt.tight_layout()

# %% [markdown]
# # 2. CNN(컨볼루션 레이어 포함) - 교안 31page

# %%
# %%time
#1. 데이터 생성 및 전처리
width = 28; height = 28
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_val = X_train[50000:]
y_val = y_train[50000:]
X_train = X_train[:50000]
y_train = y_train[:50000]
# 독립변수 (28,28) => 784 1차원 -> 실수형변환 -> 스케일조정
X_train = X_train.reshape(-1, width*height).astype(np.float32)/255.0
X_val = X_val.reshape(-1, width*height).astype(np.float32)/255.0
X_test = X_test.reshape(-1, width*height).astype(np.float32)/255.0
# 타겟변수 원핫인코딩
Y_train = to_categorical(y_train)
Y_val = to_categorical(y_val)
Y_test = to_categorical(y_test)

X_train.shape, Y_train.shape, X_val.shape, Y_val.shape, X_test.shape, Y_test.shape

# 2. 모델 구성
model = Sequential([
    Input(shape=(width*height,)),
    Dense(1024, activation='relu'),
    Dropout(0.3),
    Dense(512, activation='relu'),
    Dropout(0.3),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])
# model.summary()

# 3. 학습설정
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 4. 학습
model.fit(X_train, Y_train,
         epochs=50,
         validation_data=(X_val, Y_val),
         verbose=1)

# %%
# 2. 모델 생성
