# %%
# 네이버 API 크롤링 단계별 학습
# 각 단계를 주석을 해제하면서 실행해보세요!

# =============================================================================
# STEP 1: 라이브러리 임포트 연습
# =============================================================================
print("STEP 1: 라이브러리 임포트")

# TODO: 필요한 라이브러리들을 임포트해보세요
# import requests
# import pandas as pd
# import json
# import os
# import re
# from dotenv import load_dotenv

print("✅ 라이브러리 임포트 완료!")

# =============================================================================
# STEP 2: 환경변수 설정 연습
# =============================================================================
print("\nSTEP 2: 환경변수 설정")

# TODO: .env 파일에서 API 키를 불러와보세요
# load_dotenv()
# client_id = os.getenv('Client_ID')
# client_secret = os.getenv('Client_Secret')

# API 키가 제대로 로드되었는지 확인 (실제 키는 출력하지 않음)
# if client_id and client_secret:
#     print("✅ API 키 로드 성공!")
#     print(f"Client ID 길이: {len(client_id)}")
# else:
#     print("❌ API 키 로드 실패. .env 파일을 확인하세요.")

# =============================================================================
# STEP 3: 텍스트 정제 함수 작성 연습
# =============================================================================
print("\nSTEP 3: 텍스트 정제 함수")

def clean_text_step_by_step(text):
    """
    텍스트 정제 함수를 단계별로 작성해보세요
    """
    print(f"원본 텍스트: {text}")
    
    # TODO 1: HTML 태그 제거
    # 힌트: re.sub(r'<.*?>', '', text) 사용
    # step1 = 
    
    # TODO 2: 특수문자 제거 (한글, 영문, 숫자, 공백만 남기기)
    # 힌트: re.sub(r'[^\w\s가-힣]', '', step1) 사용
    # step2 = 
    
    # TODO 3: 앞뒤 공백 제거
    # 힌트: .strip() 사용
    # result = 
    
    # print(f"정제된 텍스트: {result}")
    # return result
    pass

# 테스트용 더러운 텍스트
test_texts = [
    "<b>전주 한옥마을</b>에서 맛있는 @비빔밥#을 먹었어요!",
    "경주 <em>불국사</em>는 정말 아름다워요~ ^^",
    "여행 계획을 세우는 중인데... 도움이 필요해요 ㅠㅠ"
]

print("텍스트 정제 테스트:")
for text in test_texts:
    # clean_text_step_by_step(text)
    print("(함수를 완성하면 결과가 나타납니다)")

# =============================================================================
# STEP 4: 단일 API 요청 연습
# =============================================================================
print("\nSTEP 4: 단일 API 요청")

def single_api_request_practice(keyword, display=10, start=1):
    """
    하나의 API 요청을 보내는 연습
    """
    # TODO 1: URL 만들기
    # base_url = "https://openapi.naver.com/v1/search/kin.json"
    # url = f"{base_url}?query={keyword}&display={display}&start={start}"
    
    # TODO 2: 헤더 설정
    # headers = {
    #     'X-Naver-Client-Id': client_id,
    #     'X-Naver-Client-Secret': client_secret
    # }
    
    # TODO 3: 요청 보내기
    # response = requests.get(url, headers=headers)
    
    # TODO 4: 응답 상태 확인
    # if response.status_code == 200:
    #     data = response.json()
    #     items = data.get('items', [])
    #     print(f"✅ API 요청 성공! {len(items)}개 결과 받음")
    #     
    #     # 첫 번째 결과 출력해보기
    #     if items:
    #         first_item = items[0]
    #         print(f"첫 번째 결과 제목: {first_item.get('title', '')}")
    #     
    #     return items
    # else:
    #     print(f"❌ API 요청 실패: {response.status_code}")
    #     return []
    
    print("(API 키를 설정하고 주석을 해제하면 실행됩니다)")
    return []

# 테스트 실행
# items = single_api_request_practice("전주여행")

# =============================================================================
# STEP 5: 여러 페이지 요청 연습
# =============================================================================
print("\nSTEP 5: 여러 페이지 요청 (페이징)")

def multiple_requests_practice(keyword, total_count=50, display=10):
    """
    여러 페이지를 요청하는 연습 (작은 숫자로 테스트)
    """
    all_items = []
    
    # TODO: range 함수로 페이징 구현
    # 힌트: range(1, total_count + 1, display)
    # for start in range(?, ?, ?):
    #     print(f"페이지 요청: start={start}, display={display}")
    #     
    #     # single_api_request_practice 함수 재활용
    #     items = single_api_request_practice(keyword, display, start)
    #     all_items.extend(items)
    #     
    #     # API 제한을 고려한 딜레이 (실제로는 필요)
    #     import time
    #     time.sleep(0.1)
    
    print(f"(완성하면 총 {len(all_items)}개의 결과를 받을 수 있습니다)")
    return all_items

# 테스트 실행
# all_results = multiple_requests_practice("전주여행", total_count=30, display=10)

# =============================================================================
# STEP 6: 데이터 정리 및 저장 연습
# =============================================================================
print("\nSTEP 6: 데이터 정리 및 저장")

def process_and_save_practice(items, keyword):
    """
    받은 데이터를 정리하고 CSV로 저장하는 연습
    """
    processed_data = []
    
    for item in items:
        # TODO: 각 item에서 필요한 정보 추출 및 정제
        # title = clean_text(item.get('title', ''))
        # link = item.get('link', '')
        # description = clean_text(item.get('description', ''))
        
        # processed_data.append([title, link, description])
        pass
    
    # TODO: DataFrame 만들기
    # df = pd.DataFrame(processed_data, columns=['title', 'link', 'description'])
    
    # TODO: CSV로 저장
    # filename = f'{keyword}_지식인검색결과_연습.csv'
    # df.to_csv(filename, index=False, encoding='utf-8-sig')
    
    # print(f"✅ {keyword} 데이터 저장 완료! 파일명: {filename}")
    # print(f"총 {len(df)}건의 데이터")
    
    print("(함수를 완성하면 CSV 파일이 생성됩니다)")

# =============================================================================
# STEP 7: 전체 통합 연습
# =============================================================================
print("\nSTEP 7: 전체 프로세스 통합")

def complete_crawling_practice():
    """
    지금까지 배운 것들을 모두 합쳐서 완전한 크롤러 만들기
    """
    # TODO: 여기에 위에서 만든 함수들을 조합해보세요
    
    keywords = ['전주여행', '경주여행']
    display = 10  # 연습용으로 작게 설정
    total_count = 20  # 연습용으로 작게 설정
    
    for keyword in keywords:
        print(f"\n{keyword} 크롤링 시작...")
        
        # 1. 여러 페이지 요청
        # items = multiple_requests_practice(keyword, total_count, display)
        
        # 2. 데이터 정리 및 저장
        # process_and_save_practice(items, keyword)
        
        print(f"{keyword} 크롤링 완료!")

# complete_crawling_practice()

# =============================================================================
# 학습 가이드
# =============================================================================
print("\n" + "="*50)
print("📚 학습 가이드")
print("="*50)
print("1. 각 STEP의 TODO 부분을 순서대로 완성하세요")
print("2. 주석을 해제하면서 하나씩 테스트해보세요") 
print("3. 에러가 나면 에러 메시지를 읽고 수정하세요")
print("4. 작은 숫자로 테스트한 후 큰 숫자로 확장하세요")
print("5. 마지막에 원본 코드와 비교해보세요")

print("\n🔥 도전 과제:")
print("- 에러 처리 추가하기 (try-except)")
print("- 진행상황 표시하기 (프로그레스 바)")
print("- 중복 제거 기능 추가하기")
print("- 다른 검색 API도 지원하기 (블로그, 뉴스 등)")

print("\n💡 팁:")
print("- 처음에는 display=5, total_count=10 같이 작게 시작하세요")
print("- API 키가 없으면 더미 데이터로 연습해보세요")
print("- 각 함수를 독립적으로 테스트해보세요")
