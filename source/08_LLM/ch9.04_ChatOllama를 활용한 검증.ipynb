# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:100% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:20pt;}
div.text_cell_render.rendered_html{font-size:18pt;}
div.text_cell_render.rendered_html{font-size:15pt;}
div.output {font-size:18pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:18pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:18pt;padding:5px;}
table.dataframe{font-size:18px;}
</style>
"""))

# %% [markdown]
# # <span style="color:red">ch9.04_ChatOllama를 활용한 검증</span>

# %% [markdown]
# # 1. 환경(패키지 및 환경변수)
#
# - pip install openai langchain-openai
# - pip install langchain-upstage
#
# - pip install langchain-ollama
# - pip install langchain-community

# %%
# %pip install langchain-community
# Out:
# ...
#
# ...
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached frozenlist-1.7.0-cp310-cp310-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached multidict-6.6.3-cp310-cp310-win_amd64.whl.metadata (5.4 kB)
# ...
#   Using cached propcache-0.3.2-cp310-cp310-win_amd64.whl.metadata (12 kB)
# ...
#   Using cached yarl-1.20.1-cp310-cp310-win_amd64.whl.metadata (76 kB)
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ------------------------------------- -- 2.4/2.5 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 10.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 9.7 MB/s eta 0:00:00
# ...
# Using cached multidict-6.6.3-cp310-cp310-win_amd64.whl (45 kB)
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
# ...

# %%
# llama3.2:1b

# %% [markdown]
# # 2. LLM 답변 생성
#
# - https://ollama.com/ 모델 검색 llama3.2:1b
# - powershell이나 cmd창에서 ollama pull llama3.2:1b
# - ollama run llama3.2

# %%
from langchain_ollama import ChatOllama
# from langchain_community.chat_models import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
ai_message = llm.invoke("2020년 월드시리즈 누가 우승했어?")
ai_message
# Out:
# AIMessage(content='2020 년 월드 시리즈는 두 팀 - 이탈리아 ACF 에이치 (ACF Aerie)와 프랑스 Ligue ASL -의 두 팀을 포함한 16 명의 선수들이 participating했습니다. \n\n이탈리아 ACF 에이치 (ACF Aerie)는 이탈리아에서 설립된 세계적으로 유명한 프로 야드 팀으로, 월드 시리즈는 3 년 연속 우승자 중 한 팀이 우승했을 때만 개최되었습니다. \n\n이탈리아 ACF 에이 Chick은 2020 월드 시리즈를 우승했습니다.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-07-29T06:01:39.0050499Z', 'done': True, 'done_reason': 'stop', 'total_duration': 12447882400, 'load_duration': 3337275800, 'prompt_eval_count': 39, 'prompt_eval_duration': 831121800, 'eval_count': 132, 'eval_duration': 8274352500, 'model_name': 'llama3.2:1b'}, id='run--ee218ca2-a2dd-4ebc-8841-d4f45801903a-0', usage_metadata={'input_tokens': 39, 'output_tokens': 132, 'total_tokens': 171})

# %% [markdown]
# # 3. 코랩에서 ollama(exaone3.5:2.4b) 돌려보기
# http://bit.ly/3IKpnVH
