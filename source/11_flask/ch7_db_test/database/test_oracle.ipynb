# %%
# pip install cx_oracle # 파이썬과 오라클을 연동하는 모듈
# pip install jupyter ipykernel # jupyter notebook 설치
# pip install pandas # pandas 모듈 설치
import cx_Oracle
import pandas as pd

conn = cx_Oracle.connect("scott", 
                        "tiger", 
                        "210.121.189.12:1521/xe") # 127.0.0.1:1521/xe, localhost:1521/xe

# %%
# SQL전송 -> 전송결과 받아 출력
cursor = conn.cursor() # SQL 전송&결과 받아주는 객체
sql = "SELECT * FROM EMP ORDER BY EMPNO"
cursor.execute(sql) # SQL 전송 + 전송결과 받기
emps = cursor.fetchall() # 전송결과 list 모두 받기(튜플 list)
# print(emps)
keys = [desc[0] for desc in cursor.description]
# emp_list = [] # 딕셔너리 list 만들기
# for emp in emps:
#   emp_dic = {}
#   for key, e in zip(keys, emp):
#     emp_dic[key] = e
#   emp_list.append(emp_dic)
emp_list = [dict(zip(keys, emp)) for emp in emps]
print(emp_list)

# %%
cursor = conn.cursor() # SQL 전송&결과 받아주는 객체
sql = "INSERT INTO EMP VALUES (:empno, :ename, 'manager', null, sysdate, 9000, 10, 40)"
empno = input("부서번호를 입력하세요: ")
ename = input("이름을 입력하세요: ")
cursor.execute(sql, {'empno':empno, 'ename':ename})
# conn.commit() # 저장 완료
print("수행 결과 :", cursor.rowcount) # 1:insert 성공, 0:실패
cursor.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 cursor = conn.cursor() # SQL 전송&결과 받아주는 객체
#       2 sql = "INSERT INTO EMP VALUES (:empno, :ename, 'manager', null, sysdate, 9000, 10, 40)"
# ----> 3 empno = input("부서번호를 입력하세요: ")
#       4 ename = input("이름을 입력하세요: ")
#       5 cursor.execute(sql, {'empno':empno, 'ename':ename})
#
# File c:\ai_x\source\11_flask\ch7_db_test\.venv\lib\site-packages\ipykernel\kernelbase.py:1260, in Kernel.raw_input(self, prompt)
#    1258     msg = "raw_input was called, but this frontend does not support input requests."
#    1259     raise StdinNotImplementedError(msg)
# -> 1260 return self._input_request(
#    1261     str(prompt),
#    1262     self._parent_ident["shell"],
#    1263     self.get_parent("shell"),
#    1264     password=False,
#    1265 )
#
# File c:\ai_x\source\11_flask\ch7_db_test\.venv\lib\site-packages\ipykernel\kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
#    1303     # re-raise KeyboardInterrupt, to truncate traceback
#    1304     msg = "Interrupted by user"
# -> 1305     raise KeyboardInterrupt(msg) from None
#    1306 except Exception:
#    1307     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
conn.close() # 연결 끊기
